# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data = {
    "Annual_Income": [15, 16, 18, 25, 40, 50, 60, 70, 80, 90, 100, 110],
    "Spending_Score": [39, 81, 6, 77, 50, 85, 70, 30, 90, 20, 60, 40]
}

df = pd.DataFrame(data)
df.head(5)
# Out:
#    Annual_Income  Spending_Score
# 0             15              39
# 1             16              81
# 2             18               6
# 3             25              77
# 4             40              50

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
print(scaled_data)
# Out:
# [[-1.26176517 -0.57104024]
#  [-1.23111501  1.02787243]
#  [-1.16981468 -1.82732877]
#  [-0.95526351  0.87559504]
#  [-0.49551102 -0.1522774 ]
#  [-0.18900936  1.18014983]
#  [ 0.1174923   0.60910959]
#  [ 0.42399397 -0.91366439]
#  [ 0.73049563  1.37049658]
#  [ 1.03699729 -1.29435788]
#  [ 1.34349895  0.2284161 ]
#  [ 1.65000061 -0.53297089]]

# %%
# Apply K-Means with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
df["Cluster"] = kmeans.fit_predict(scaled_data)

# Print the cluster assignments
print(df)
# Out:
#     Annual_Income  Spending_Score  Cluster
# 0              15              39        0
# 1              16              81        2
# 2              18               6        0
# 3              25              77        2
# 4              40              50        0
# 5              50              85        2
# 6              60              70        2
# 7              70              30        1
# 8              80              90        2
# 9              90              20        1
# 10            100              60        1
# 11            110              40        1

# %%
# Plot the clusters
plt.scatter(df["Annual_Income"], df["Spending_Score"], c=df["Cluster"], cmap="rainbow", edgecolors="k", s=100)
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Segmentation using K-Means Clustering")
plt.colorbar(label="Cluster")
plt.show()
